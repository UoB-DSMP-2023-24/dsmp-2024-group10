# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file containing the distance matrix
file_path = 'array.csv'  # Replace with your actual file path
data = pd.read_csv(file_path)

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(data, cmap='viridis', xticklabels=False, yticklabels=False)
plt.title('Distance Matrix Visualization')
plt.xlabel('Points')
plt.ylabel('Points')
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# Load the distance matrix from the CSV file
file_path = 'array.csv'
data = pd.read_csv(file_path, header=None)

# Create a graph from the distance matrix
G = nx.Graph()

# Add edges to the graph (nodes are added automatically)
for i in range(1, len(data)):  # Assuming the first column & row are labels
    for j in range(1, len(data.columns)):
        if i != j:
            # Add an edge between node i and j, with the distance as the weight
            G.add_edge(data.iloc[i, 0], data.iloc[j, 0], weight=data.iloc[i, j])

# Visualize the graph
plt.figure(figsize=(12, 12))
pos = nx.spring_layout(G)  # Positions for all nodes

# Nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# Edges
weights = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx
# Out:
# <function networkx.drawing.nx_pylab.draw_networkx(G, pos=None, arrows=None, with_labels=True, **kwds)>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file containing the distance matrix
file_path = 'array_cdr3_a.csv'  # Replace with your actual file path
data = pd.read_csv(file_path)

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(data, cmap='viridis', xticklabels=False, yticklabels=False)
plt.title('Distance Matrix Visualization')
plt.xlabel('Points')
plt.ylabel('Points')
plt.show()
